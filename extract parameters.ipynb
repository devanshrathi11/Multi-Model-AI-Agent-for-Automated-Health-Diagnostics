# %%
import pandas as pd
def extract_key_parameters(path):
    df = pd.read_csv(path)
    print("\n Identified Key Parameters:\n")
    for col in df.columns:
        print(f"- {col}")
    return df.columns.tolist()
if __name__ == "__main__":
    extract_key_parameters("healthcare_dataset.csv")
# Out:
#  Identified Key Parameters:
#
# - Name
# - Age
# - Gender
# - Blood Type
# - Medical Condition
# - Date of Admission
# - Doctor
# - Hospital
# - Insurance Provider
# - Billing Amount
# - Room Number
# - Admission Type
# - Discharge Date
# - Medication
# - Test Results
